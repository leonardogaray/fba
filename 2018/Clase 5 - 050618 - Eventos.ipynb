// %% [markdown]
// # Funciones
//
// ## dist(posX1, posY1, posX2, posY2)
// Esta función nos permite ver la distancia que existe entre dos puntos

// %%
int posX_P1;
int posY_P1; 
int posX_P2;
int posY_P2;

void setup(){
    size(400, 400);
    textSize(20);
    
    posX_P1 = 100;
    posY_P1 = 100; 
    posX_P2 = 300;
    posY_P2 = 300;
}
void draw(){
    background(200);
    text("Distancia entre P1 y P2 :" + dist(posX_P1, posY_P1, posX_P2, posY_P2), 10, 50);
    line(posX_P1, posY_P1, posX_P2, posY_P2);
}
// Out:
// <div id="canvas_div_1">
//   <b>Sketch #1:</b><br/>
//   <canvas id="canvas_1"></canvas><br/>
// </div>
// <div id="controls_div_1">
//   <button id="run_button_1" onclick="startSketch('1');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_1" onclick="pauseSketch('1');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_1" onclick="setupSketch('1');">
//     setup()
//   </button>
//   <button id="draw_button_1" onclick="drawSketch('1');">
//     draw()
//   </button>
// </div>
// <b>Sketch #1 state:</b> <span id="state_1">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// Podemos tambien ir viendo como la distancia varía cuando uno de los puntos se encuentra relacionado con variables. Tomemos como ejemplo una ellipse que se va alejando del origen (0,0)

// %%
int posX_P1;
int posY_P1; 
int posX_P2;
int posY_P2;
void setup(){
    size(400, 400);
    textSize(20);
    
    posX_P1 = 0;
    posY_P1 = 0; 
    posX_P2 = 0;
    posY_P2 = 0;
}
void draw(){
    background(200);
    text("Distancia entre P1 y P2 :" + dist(posX_P1, posY_P1, posX_P2, posY_P2), 10, 50);
    line(posX_P1, posY_P1, posX_P2, posY_P2);
    ellipse(posX_P2, posY_P2, 10, 10);
    posX_P2++;
    posY_P2++;
}
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// O podemos ver como se afecta la distancia en 2 puntos en movimiento, alejandose entre ellos

// %%
int posX_P1;
int posY_P1; 
int posX_P2;
int posY_P2;
void setup(){
    size(400, 400);
    textSize(20);
    
    posX_P1 = width/2;
    posY_P1 = height/2; 
    posX_P2 = width/2;
    posY_P2 = height/2;
}
void draw(){
    background(200);
    text("Distancia entre P1 y P2 :" + dist(posX_P1, posY_P1, posX_P2, posY_P2), 10, 50);
    line(posX_P1, posY_P1, posX_P2, posY_P2);
    ellipse(posX_P1, posY_P1, 10, 10);
    ellipse(posX_P2, posY_P2, 10, 10);
    posX_P1++;
    posX_P2--;
}
// Out:
// <div id="canvas_div_3">
//   <b>Sketch #3:</b><br/>
//   <canvas id="canvas_3"></canvas><br/>
// </div>
// <div id="controls_div_3">
//   <button id="run_button_3" onclick="startSketch('3');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_3" onclick="pauseSketch('3');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_3" onclick="setupSketch('3');">
//     setup()
//   </button>
//   <button id="draw_button_3" onclick="drawSketch('3');">
//     draw()
//   </button>
// </div>
// <b>Sketch #3 state:</b> <span id="state_3">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ## map(valor, rango1_inicio, rango1_fin, rango2_inicio, rango2_fin)
// Esta función permite calcular cual es el la proporción de un valor dentro de un rango de valores, ubicado en otro rango de valores.
// Por ejemplo, supongamos un rango de valores entre 0 y 100. Si tomamos el valor 50, vemos que este valor corresponde a la mitad del rango indicado. Pero que sucede si yo quiero llevar ese valor a otro rango, por ejemplo un rango de valores que va desde 0 hasta 200. El equivalente sería 100.
// Otro ejemplo, supongamos un rango de valores que va desde 0 hasta 400, pero yo solo quiero obtener ese rango dividio en 10 partes, o sea, el nuevo rango sería entre 0 y 10. Esta función me retornaría para un valor igual a 200 .... un 5 (la mitad del rango).

// %% [markdown]
// Veamos el siguiente ejemplo, donde se arealiza una animación de un rectangulo avanzando de a 1 pixel hacia la derecha, y otro rectángulo aplicando la función map.

// %%
int posX_P1;
float posX_P2;
float posX_P3;
int tam;
int max;
void setup(){
    size(400, 400);
    textSize(20);
    frameRate(5);
    max = 10;
    tam = round(width/max);
    posX_P1 = 0;
    posX_P2 = 0;
    posX_P3 = 0;
}
void draw(){
    background(200);
    text("Valor posX_P1 : " + posX_P1, 10, 200);
    text("Valor posX_P2 : " + posX_P2, 10, 250);
    text("Valor floor(posX_P2) * tam: " + posX_P3, 10, 300);
    rect(posX_P1, 0, tam, tam);
    rect(posX_P2, 50, tam, tam);
    rect(posX_P3, 100, tam, tam);
    posX_P1++;
    posX_P2 = map(posX_P1, 0, width, 0, 10);
    posX_P3 = floor(posX_P2) * tam;
}
// Out:
// <div id="canvas_div_8">
//   <b>Sketch #8:</b><br/>
//   <canvas id="canvas_8"></canvas><br/>
// </div>
// <div id="controls_div_8">
//   <button id="run_button_8" onclick="startSketch('8');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_8" onclick="pauseSketch('8');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_8" onclick="setupSketch('8');">
//     setup()
//   </button>
//   <button id="draw_button_8" onclick="drawSketch('8');">
//     draw()
//   </button>
// </div>
// <b>Sketch #8 state:</b> <span id="state_8">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// Generamos rectángulos en posiciones aleatorias de la pantalla, pero dividiendo la pantalla en una grilla de 15 de ancho (columnas) por 7 de alto (filas)

// %%
float posX;
float posY;
int tamX, tamY;
int col;
int fila;

void setup(){
    size(400, 400);
    col = 15;
    fila = 7;
    tamX = width / col;
    tamY = height / fila;
}
void draw(){
    posX = floor(map(random(0,width),0, width, 0, 15)) * tamX;
    posY = floor(map(random(0,height),0, width, 0, 7)) * tamY;
    rect(posX, posY, tamX, tamY);
    
}
// Out:
// <div id="canvas_div_9">
//   <b>Sketch #9:</b><br/>
//   <canvas id="canvas_9"></canvas><br/>
// </div>
// <div id="controls_div_9">
//   <button id="run_button_9" onclick="startSketch('9');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_9" onclick="pauseSketch('9');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_9" onclick="setupSketch('9');">
//     setup()
//   </button>
//   <button id="draw_button_9" onclick="drawSketch('9');">
//     draw()
//   </button>
// </div>
// <b>Sketch #9 state:</b> <span id="state_9">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// Generamos elipses con borde de color verde en posiciones aleatorias de la pantalla, pero con un color de transparencia proporcional a la distancia que poseen las mismas con respecto al centro de la pantalla. A medida que mas cerca se encuentran del centro, mas transparentes son.

// %%
float posX;
float posY;
float distancia;
float miColor;

void setup(){
    size(400, 400);
    background(0);
}
void draw(){
    noFill();
    posX = random(0, width);
    posY = random(0, height);
    distancia = dist(width/2, height/2, posX, posY);
    miColor = map(distancia, 0, width/2, 0, 100);
    stroke(0, 255, 0, miColor);
    ellipse(posX, posY, 30, 30);    
}
// Out:
// <div id="canvas_div_10">
//   <b>Sketch #10:</b><br/>
//   <canvas id="canvas_10"></canvas><br/>
// </div>
// <div id="controls_div_10">
//   <button id="run_button_10" onclick="startSketch('10');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_10" onclick="pauseSketch('10');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_10" onclick="setupSketch('10');">
//     setup()
//   </button>
//   <button id="draw_button_10" onclick="drawSketch('10');">
//     draw()
//   </button>
// </div>
// <b>Sketch #10 state:</b> <span id="state_10">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
//  # Eventos
//
//  ## mouseX y mouseY
//  Al movernos por la pantalla, podemos obtener las posiciones en X e Y en las que se encuentra el mouse. Estas variables son mouseX y mouseY

// %%
void setup(){
    size(400, 400);
    textSize(30);
}
void draw(){
    background(200);
    text("mouseX: " + mouseX, 100,100);
    text("mouseY: " + mouseY, 100,200);
    line(0,0, mouseX, mouseY);
}
// Out:
// <div id="canvas_div_11">
//   <b>Sketch #11:</b><br/>
//   <canvas id="canvas_11"></canvas><br/>
// </div>
// <div id="controls_div_11">
//   <button id="run_button_11" onclick="startSketch('11');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_11" onclick="pauseSketch('11');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_11" onclick="setupSketch('11');">
//     setup()
//   </button>
//   <button id="draw_button_11" onclick="drawSketch('11');">
//     draw()
//   </button>
// </div>
// <b>Sketch #11 state:</b> <span id="state_11">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// Ahora, trabajamos generando líneas que salen de las esquinas de la pantalla, pero cada una se hace mas transparente cuanto mas cerca se encuentra de la esquina de la cual se origina.

// %%
float distancia;
float miColor;

void setup(){
    size(400, 400);
}
void draw(){
    distancia = dist(0, 0, mouseX, mouseY);
    miColor = map(distancia, 0, width, 0, 100);
    stroke(0, 255, 0, miColor);
    line(0,0, mouseX, mouseY);
    
    distancia = dist(width, 0, mouseX, mouseY);
    miColor = map(distancia, 0, width, 0, 100);
    stroke(0, 255, 0, miColor);
    line(width,0, mouseX, mouseY);
    
    distancia = dist(0, height, mouseX, mouseY);
    miColor = map(distancia, 0, width, 0, 100);
    stroke(0, 255, 0, miColor);
    line(0,height, mouseX, mouseY);
    
    distancia = dist(width, height, mouseX, mouseY);
    miColor = map(distancia, 0, width, 0, 100);
    stroke(0, 255, 0, miColor);
    line(width,height, mouseX, mouseY);
}
// Out:
// <div id="canvas_div_7">
//   <b>Sketch #7:</b><br/>
//   <canvas id="canvas_7"></canvas><br/>
// </div>
// <div id="controls_div_7">
//   <button id="run_button_7" onclick="startSketch('7');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_7" onclick="pauseSketch('7');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_7" onclick="setupSketch('7');">
//     setup()
//   </button>
//   <button id="draw_button_7" onclick="drawSketch('7');">
//     draw()
//   </button>
// </div>
// <b>Sketch #7 state:</b> <span id="state_7">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// Modificamos el color de relleno de un rectángulo al mover el mouse a lo ancho, y su transparencia al moverlo en lo ancho de la pantalla

// %%
float miColor;
float miAlpha;

void setup(){
    size(400, 400);
    rectMode(CENTER);
}
void draw(){
    background(200);
    noStroke();
    miColor = map(mouseX, 0, width, 0, 255);
    miAlpha = map(mouseY, 0, height, 0, 255);
    fill(0, miColor, 0, miAlpha);
    rect(width/2,height/2, 100, 100);
}
// Out:
// <div id="canvas_div_13">
//   <b>Sketch #13:</b><br/>
//   <canvas id="canvas_13"></canvas><br/>
// </div>
// <div id="controls_div_13">
//   <button id="run_button_13" onclick="startSketch('13');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_13" onclick="pauseSketch('13');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_13" onclick="setupSketch('13');">
//     setup()
//   </button>
//   <button id="draw_button_13" onclick="drawSketch('13');">
//     draw()
//   </button>
// </div>
// <b>Sketch #13 state:</b> <span id="state_13">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// A medida que el mouse se mueve, una elipse acompaña al mismo, y va quedando un rastro que va desapareciendo

// %%
void setup(){
    size(400, 400);
    noStroke();
}
void draw(){
    fill(0,200,0);
    ellipse(mouseX,mouseY, 100, 100);
    fill(255,10);
    rect(0,0,width, height);
}
// Out:
// <div id="canvas_div_12">
//   <b>Sketch #12:</b><br/>
//   <canvas id="canvas_12"></canvas><br/>
// </div>
// <div id="controls_div_12">
//   <button id="run_button_12" onclick="startSketch('12');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_12" onclick="pauseSketch('12');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_12" onclick="setupSketch('12');">
//     setup()
//   </button>
//   <button id="draw_button_12" onclick="drawSketch('12');">
//     draw()
//   </button>
// </div>
// <b>Sketch #12 state:</b> <span id="state_12">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// Al mover el mouse, una elipse acompaña el movimiento del mismo. Al hacer click cambia a color verde. Al tener presionado cualquier botón del mouse, cambia a azul. Al soltar el botón cambia a color rojo. Al presionar una tecla, se borra la pantalla.

// %%
void setup(){
    size(400, 400);
}
void draw(){
    ellipse(mouseX,mouseY, 100, 100);
}
void mouseClicked(){
    fill(0,255,0);
}
void mousePressed(){
    fill(0,0,255);
}
void mouseReleased(){
    fill(255,0,0);
}
void keyPressed(){
    background(200);
}
// Out:
// <div id="canvas_div_14">
//   <b>Sketch #14:</b><br/>
//   <canvas id="canvas_14"></canvas><br/>
// </div>
// <div id="controls_div_14">
//   <button id="run_button_14" onclick="startSketch('14');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_14" onclick="pauseSketch('14');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_14" onclick="setupSketch('14');">
//     setup()
//   </button>
//   <button id="draw_button_14" onclick="drawSketch('14');">
//     draw()
//   </button>
// </div>
// <b>Sketch #14 state:</b> <span id="state_14">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// Dibujar 4 ellipses que acompañen el movimiento del mouse en X, pero que cada una se mueva a la mitad de la que acompaña el mouse. Las velocidades deben ser 1x, 1/2x, 1/4x, 1/8x.

// %%
float posX;

void setup(){
    size(400, 400);
}
void draw(){
  background(200);
  posX = map(mouseX, 0, width, 175, 225);
  ellipse(posX, 50, 50, 50);
  posX = map(mouseX, 0, width, 150, 250);
  ellipse(posX, 100, 50, 50);
  posX = map(mouseX, 0, width, 100, 300);
  ellipse(posX, 150, 50, 50);
  ellipse(mouseX, 200, 50, 50);
}
// Out:
// <div id="canvas_div_15">
//   <b>Sketch #15:</b><br/>
//   <canvas id="canvas_15"></canvas><br/>
// </div>
// <div id="controls_div_15">
//   <button id="run_button_15" onclick="startSketch('15');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_15" onclick="pauseSketch('15');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_15" onclick="setupSketch('15');">
//     setup()
//   </button>
//   <button id="draw_button_15" onclick="drawSketch('15');">
//     draw()
//   </button>
// </div>
// <b>Sketch #15 state:</b> <span id="state_15">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// Al presionar una tecla, mover un paisaje de fondo en una dirección

// %%
float posX;
PImage paisaje;

void setup(){
    size(400, 400);
    paisaje = loadImage("clase5/paisaje.jpg");
}
void draw(){
    image(paisaje, posX, 0, 3000, height);
}
void keyPressed(){
    posX--;
}
// Out:
// <div id="canvas_div_19">
//   <b>Sketch #19:</b><br/>
//   <canvas id="canvas_19"></canvas><br/>
// </div>
// <div id="controls_div_19">
//   <button id="run_button_19" onclick="startSketch('19');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_19" onclick="pauseSketch('19');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_19" onclick="setupSketch('19');">
//     setup()
//   </button>
//   <button id="draw_button_19" onclick="drawSketch('19');">
//     draw()
//   </button>
// </div>
// <b>Sketch #19 state:</b> <span id="state_19">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...
