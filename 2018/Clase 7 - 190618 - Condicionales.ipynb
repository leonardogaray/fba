// %% [markdown]
// # Condicionales

// %% [markdown]
// ## Ejercicio Repaso
// Dadas 2 zonas, donde una arranca en 100 X hasta 200 X y otra desde 300 X hasta 400 X, lograr que se pueda escribiri como si fuese con un lapiz en dichas zonas. TIP: line(mouseX, mouseY, pmouseX, pmouseY)

// %%
void setup(){
    size(500,200);
}
void draw(){
    if(mouseX>100 && mouseX<200){
        line(mouseX, mouseY, pmouseX, pmouseY);
    }else if(mouseX>300 && mouseX<400){
        line(mouseX, mouseY, pmouseX, pmouseY);
    }
}
// Out:
// <div id="canvas_div_5">
//   <b>Sketch #5:</b><br/>
//   <canvas id="canvas_5"></canvas><br/>
// </div>
// <div id="controls_div_5">
//   <button id="run_button_5" onclick="startSketch('5');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_5" onclick="pauseSketch('5');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_5" onclick="setupSketch('5');">
//     setup()
//   </button>
//   <button id="draw_button_5" onclick="drawSketch('5');">
//     draw()
//   </button>
// </div>
// <b>Sketch #5 state:</b> <span id="state_5">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %%
void setup(){
    size(500,200);
}
void draw(){
    if((mouseX>100 && mouseX<200) || 
       (mouseX>300 && mouseX<400)){
        line(mouseX, mouseY, pmouseX, pmouseY);
    }
}
// Out:
// <div id="canvas_div_6">
//   <b>Sketch #6:</b><br/>
//   <canvas id="canvas_6"></canvas><br/>
// </div>
// <div id="controls_div_6">
//   <button id="run_button_6" onclick="startSketch('6');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_6" onclick="pauseSketch('6');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_6" onclick="setupSketch('6');">
//     setup()
//   </button>
//   <button id="draw_button_6" onclick="drawSketch('6');">
//     draw()
//   </button>
// </div>
// <b>Sketch #6 state:</b> <span id="state_6">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ## Menú con Drag

// %%
int posX;
String texto;
void setup(){
    size(400,200);
    //Posicion de la zona que vamos a draguear
    posX = 100;
    texto = "Nada Presionado";
}
void draw(){
    background(200);
    //Primer boton
    fill(0);
    text("A", 120, 130);
    noFill();
    rect(100,100,50,50);
    //Segundo boton
    fill(0);
    text("B", 170, 130);
    noFill();
    rect(150,100,50,50);
    //Tercer boton
    fill(0);
    text("C", 220, 130);
    noFill();
    rect(200,100,50,50);
    //Cuarto boton
    fill(0);
    text("D", 270, 130);
    noFill();
    rect(250,100,50,50);
    //Zona a draguear
    fill(255);
    rect(posX, 100, 200, 50);
    fill(0);
    //Texto indicador de boton presionado
    text(texto, 100, 50);
}
void mouseDragged(){
    if(mouseX > 100 && mouseX < 300){
        posX = mouseX;
    }
}
void mouseClicked(){
    if(mouseX > 100 && mouseX < posX){
        if(mouseX > 100 && mouseX < 150 && mouseY > 100 && mouseY < 150){
            texto = "Presionado A";
        }else if(mouseX > 150 && mouseX < 200 && mouseY > 100 && mouseY < 150){
            texto = "Presionado B";
        }else if(mouseX > 200 && mouseX < 250 && mouseY > 100 && mouseY < 150){
            texto = "Presionado C";
        }else if(mouseX > 250 && mouseX < 300 && mouseY > 100 && mouseY < 150){
            texto = "Presionado D";
        }
    }else{
        texto = "Nada Presionado";
    }
}
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ### Menu Dragueable - Paso 1

// %%
void setup(){
    size(400,300);
}
void draw(){
    noFill();
    rect(100,200,50,50);
    rect(150,200,50,50);
    rect(200,200,50,50);
    rect(250,200,50,50);
    fill(0);
    text("A",120, 225);
    text("B",170, 225);
    text("C",220, 225);
    text("D",270, 225);
}
// Out:
// <div id="canvas_div_13">
//   <b>Sketch #13:</b><br/>
//   <canvas id="canvas_13"></canvas><br/>
// </div>
// <div id="controls_div_13">
//   <button id="run_button_13" onclick="startSketch('13');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_13" onclick="pauseSketch('13');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_13" onclick="setupSketch('13');">
//     setup()
//   </button>
//   <button id="draw_button_13" onclick="drawSketch('13');">
//     draw()
//   </button>
// </div>
// <b>Sketch #13 state:</b> <span id="state_13">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ### Menu Dragueable - Paso 2

// %%
String miTexto;
void setup(){
    size(400,300);
    miTexto = "Nada Presionado";
}
void draw(){
    background(200);
    text(miTexto, 100, 100);
    noFill();
    rect(100,200,50,50);
    rect(150,200,50,50);
    rect(200,200,50,50);
    rect(250,200,50,50);
    fill(0);
    text("A",120, 225);
    text("B",170, 225);
    text("C",220, 225);
    text("D",270, 225);
}
// Out:
// <div id="canvas_div_15">
//   <b>Sketch #15:</b><br/>
//   <canvas id="canvas_15"></canvas><br/>
// </div>
// <div id="controls_div_15">
//   <button id="run_button_15" onclick="startSketch('15');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_15" onclick="pauseSketch('15');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_15" onclick="setupSketch('15');">
//     setup()
//   </button>
//   <button id="draw_button_15" onclick="drawSketch('15');">
//     draw()
//   </button>
// </div>
// <b>Sketch #15 state:</b> <span id="state_15">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ### Menu Dragueable - Paso 3

// %%
String miTexto;
void setup(){
    size(400,300);
    miTexto = "Nada Presionado";
}
void draw(){
    background(200);
    text(miTexto, 100, 100);
    noFill();
    rect(100,200,50,50);
    rect(150,200,50,50);
    rect(200,200,50,50);
    rect(250,200,50,50);
    fill(0);
    text("A",120, 225);
    text("B",170, 225);
    text("C",220, 225);
    text("D",270, 225);
}
void mouseClicked(){
    if(mouseX>100 && mouseX<150 && mouseY>200 && mouseY<250){
        miTexto = "Presionado A";
    }else if(mouseX>150 && mouseX<200 && mouseY>200 && mouseY<250){
        miTexto = "Presionado B";
    }else if(mouseX>200 && mouseX<250 && mouseY>200 && mouseY<250){
        miTexto = "Presionado C";
    }else if(mouseX>250 && mouseX<300 && mouseY>200 && mouseY<250){
        miTexto = "Presionado D";
    }else{
        miTexto = "Nada Presionado";
    }
}
// Out:
// <div id="canvas_div_17">
//   <b>Sketch #17:</b><br/>
//   <canvas id="canvas_17"></canvas><br/>
// </div>
// <div id="controls_div_17">
//   <button id="run_button_17" onclick="startSketch('17');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_17" onclick="pauseSketch('17');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_17" onclick="setupSketch('17');">
//     setup()
//   </button>
//   <button id="draw_button_17" onclick="drawSketch('17');">
//     draw()
//   </button>
// </div>
// <b>Sketch #17 state:</b> <span id="state_17">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ### Menu Dragueable - Paso 4

// %%
String miTexto;
int posX;
void setup(){
    size(400,300);
    miTexto = "Nada Presionado";
    posX = 100;
}
void draw(){
    background(200);
    fill(0);
    text(miTexto, 100, 100);
    noFill();
    rect(100,200,50,50);
    rect(150,200,50,50);
    rect(200,200,50,50);
    rect(250,200,50,50);
    fill(0);
    text("A",120, 225);
    text("B",170, 225);
    text("C",220, 225);
    text("D",270, 225);
    fill(255);
    rect(posX,200,300,50);
    
}
void mouseClicked(){
    if(posX >= 280){
        if(mouseX>100 && mouseX<150 && mouseY>200 && mouseY<250){
            miTexto = "Presionado A";
        }else if(mouseX>150 && mouseX<200 && mouseY>200 && mouseY<250){
            miTexto = "Presionado B";
        }else if(mouseX>200 && mouseX<250 && mouseY>200 && mouseY<250){
            miTexto = "Presionado C";
        }else if(mouseX>250 && mouseX<300 && mouseY>200 && mouseY<250){
            miTexto = "Presionado D";
        }else{
            miTexto = "Nada Presionado";
        }
    }
}
void mouseDragged(){
    if(mouseX>100 && mouseX<300){
        posX = mouseX;
    }
}
// Out:
// <div id="canvas_div_22">
//   <b>Sketch #22:</b><br/>
//   <canvas id="canvas_22"></canvas><br/>
// </div>
// <div id="controls_div_22">
//   <button id="run_button_22" onclick="startSketch('22');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_22" onclick="pauseSketch('22');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_22" onclick="setupSketch('22');">
//     setup()
//   </button>
//   <button id="draw_button_22" onclick="drawSketch('22');">
//     draw()
//   </button>
// </div>
// <b>Sketch #22 state:</b> <span id="state_22">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ## Menú Clonado

// %%
int posX, posY, incrementoBoton1, incrementoBoton2, incrementoBoton3;
boolean iniciarAnimacionMostrar, finAnimacionMostrar, iniciarAnimacionOcultar;
String texto;
void setup(){
    size(400,200);
    posX = 100;
    posY = 100;
    iniciarAnimacionMostrar = false;
    iniciarAnimacionOcultar = false;
    incrementoBoton1 = 0; incrementoBoton2 = 0; incrementoBoton3 = 0;
    texto = "Nada Presionado";
}
void draw(){
    background(200);
    //Animacion mostrando los botones
    if(iniciarAnimacionMostrar && !finAnimacionMostrar){
       if(incrementoBoton1 < 100){ 
           incrementoBoton1+=1; 
       }
       if(incrementoBoton2 < 150){ 
           incrementoBoton2+=2; 
       }
       if(incrementoBoton3 < 200){ 
           incrementoBoton3+=3; 
       } 
       if(incrementoBoton3 >= 200){
           finAnimacionMostrar = true;
       }
    }
    //Animacion ocultando los botones
    if(iniciarAnimacionOcultar){
       if(incrementoBoton1 > 0){ 
           incrementoBoton1-=1; 
       }
       if(incrementoBoton2 > 0){ 
           incrementoBoton2-=2; 
       }
       if(incrementoBoton3 > 0){ 
           incrementoBoton3-=3; 
       } 
       if(incrementoBoton3 <= 0){
           //Reset de las ariables para volver a arrancar la animacion
           incrementoBoton1 = 0;
           incrementoBoton2 = 0;
           incrementoBoton3 = 0;
           iniciarAnimacionMostrar = false;
           iniciarAnimacionOcultar = false;
           finAnimacionMostrar = false;
       }
    }
    //Boton 1
    fill(255);
    ellipse(posX + incrementoBoton1, posY, 30, 30);
    fill(0);
    text("A", posX + incrementoBoton1 - 5, posY);
    //Boton 2
    fill(255);
    ellipse(posX + incrementoBoton2, posY, 30, 30);
    fill(0);
    text("B", posX + incrementoBoton2 - 5, posY);
    //Boton 3
    fill(255);
    ellipse(posX + incrementoBoton3, posY, 30, 30);
    fill(0);
    text("C", posX + incrementoBoton3 - 5, posY);
    //Menu
    fill(255);
    ellipse(posX, posY, 50, 50);
    //Texto indicador de boton presionado
    fill(0);
    text(texto, 100, 50);
}
void mouseClicked(){
    if(dist(mouseX, mouseY, posX, posY) < 25){
        if(!iniciarAnimacionMostrar){
            iniciarAnimacionMostrar = !iniciarAnimacionMostrar;
        }else if(!iniciarAnimacionOcultar && finAnimacionMostrar){
            iniciarAnimacionOcultar = !iniciarAnimacionOcultar;
        }
    }
    if(finAnimacionMostrar){
        if(dist(mouseX, mouseY, posX + incrementoBoton1, posY) < 15){
            texto = "Presionado A";
        }else if(dist(mouseX, mouseY, posX + incrementoBoton2, posY) < 15){
            texto = "Presionado B";
        }else if(dist(mouseX, mouseY, posX + incrementoBoton3, posY) < 15){
            texto = "Presionado C";
        }else{
            texto = "Nada Presionado";
        }
    }
}
// Out:
// <div id="canvas_div_4">
//   <b>Sketch #4:</b><br/>
//   <canvas id="canvas_4"></canvas><br/>
// </div>
// <div id="controls_div_4">
//   <button id="run_button_4" onclick="startSketch('4');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_4" onclick="pauseSketch('4');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_4" onclick="setupSketch('4');">
//     setup()
//   </button>
//   <button id="draw_button_4" onclick="drawSketch('4');">
//     draw()
//   </button>
// </div>
// <b>Sketch #4 state:</b> <span id="state_4">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ## Rebote

// %%
int posX, dir, velocidad;
void setup(){
    size(400,400);
    posX = 200;
    //Direccion derecha o izquierda, dependiendo de si vale 1 o -1
    dir = 1;
    velocidad = 5;
}
void draw(){
    background(200);
    ellipse(posX, 200, 50, 50);
    //Si posX supera el margen derecho o izquierdo, cambio el sentido.
    if(posX > width - 25 || posX < 25){
        dir = dir * -1;
    }
    posX += dir * velocidad;
}
// Out:
// <div id="canvas_div_23">
//   <b>Sketch #23:</b><br/>
//   <canvas id="canvas_23"></canvas><br/>
// </div>
// <div id="controls_div_23">
//   <button id="run_button_23" onclick="startSketch('23');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_23" onclick="pauseSketch('23');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_23" onclick="setupSketch('23');">
//     setup()
//   </button>
//   <button id="draw_button_23" onclick="drawSketch('23');">
//     draw()
//   </button>
// </div>
// <b>Sketch #23 state:</b> <span id="state_23">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ## Rebote - Repaso en clase

// %%
int posX, dir, vel;
void setup(){
    size(400,400);
    posX = 200;
    dir = 1;
    vel = 5;
}
void draw(){
    background(200);
    ellipse(posX,200,50,50);
    if(posX>=width-25){
        dir = -1;
    }else if(posX<25){
        dir = 1;
    }
    
    posX = posX + dir * vel;
}
// Out:
// <div id="canvas_div_30">
//   <b>Sketch #30:</b><br/>
//   <canvas id="canvas_30"></canvas><br/>
// </div>
// <div id="controls_div_30">
//   <button id="run_button_30" onclick="startSketch('30');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_30" onclick="pauseSketch('30');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_30" onclick="setupSketch('30');">
//     setup()
//   </button>
//   <button id="draw_button_30" onclick="drawSketch('30');">
//     draw()
//   </button>
// </div>
// <b>Sketch #30 state:</b> <span id="state_30">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ## Rebote con Obstáculo

// %%
int posX, dir, velocidad;
void setup(){
    size(400,400);
    posX = 200;
    //Direccion derecha o izquierda, dependiendo de si vale 1 o -1
    dir = 1;
    velocidad = 5;
}
void draw(){
    background(200);
    ellipse(posX, 200, 50, 50);
    //Si posX supera el margen derecho o izquierdo, cambio el sentido.
    if(posX > width - 25 || posX < 25){
        dir = dir * -1;
    }
    posX += dir * velocidad;
    
    //Dibujo el obstaculo en el centro de la pantalla que solo se mueve con el mouseY
    rect(200, mouseY, 50, 100);
    //Hago que cambie la direccion si la elipse colisiona con el lado derecho del rectangulo del centro
    if(posX + 25 > 200 && posX + 25 < 250 && 200 > mouseY && 200 < mouseY + 100){
        dir = dir * -1;
    }
    //Hago que cambie la direccion si la elipse colisiona con el lado izquierdo del rectangulo del centro
    if(posX - 25 > 200 && posX - 25 < 250 && 200 > mouseY && 200 < mouseY + 100){
        dir = dir * -1;
    }
}
// Out:
// <div id="canvas_div_31">
//   <b>Sketch #31:</b><br/>
//   <canvas id="canvas_31"></canvas><br/>
// </div>
// <div id="controls_div_31">
//   <button id="run_button_31" onclick="startSketch('31');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_31" onclick="pauseSketch('31');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_31" onclick="setupSketch('31');">
//     setup()
//   </button>
//   <button id="draw_button_31" onclick="drawSketch('31');">
//     draw()
//   </button>
// </div>
// <b>Sketch #31 state:</b> <span id="state_31">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// ## Rebote con Obstáculo - Repaso en clase

// %%
int posX, dir, vel;
void setup(){
    size(400,400);
    posX = 200;
    dir = 1;
    vel = 5;
}
void draw(){
    background(200);
    ellipse(posX,200,50,50);
    if(posX>=width-25){
        dir = -1;
    }else if(posX<25){
        dir = 1;
    }else if(mouseY>100 && mouseY<225){
        if(posX + 25 > 200 && posX + 25 < 250){
            dir = dir * -1;
        }
        if(posX - 25 > 200 && posX - 25 < 250){
            dir = dir * -1;
        }
    }
    
    posX = posX + dir * vel;
    
    rect(200,mouseY,50,100);
}
// Out:
// <div id="canvas_div_47">
//   <b>Sketch #47:</b><br/>
//   <canvas id="canvas_47"></canvas><br/>
// </div>
// <div id="controls_div_47">
//   <button id="run_button_47" onclick="startSketch('47');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_47" onclick="pauseSketch('47');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_47" onclick="setupSketch('47');">
//     setup()
//   </button>
//   <button id="draw_button_47" onclick="drawSketch('47');">
//     draw()
//   </button>
// </div>
// <b>Sketch #47 state:</b> <span id="state_47">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...
